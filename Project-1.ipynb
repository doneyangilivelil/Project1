# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')

# %%
df .head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df1 .head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %% [markdown]
# Get the Metadata from the above files.

# %%
df.dtypes
df.info()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 327.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# ...

# %% [markdown]
#  Get the row names from the above files.

# %%
print(df1.index)
# Out:
# RangeIndex(start=0, stop=117208, step=1)

# %% [markdown]
# Change the column name from any of the above file.

# %%
df.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df.rename(columns={"Indicator":"Indicator_Id"},inplace=False).head(3)
# Out:
#                         Indicator_Id PUBLISH STATES  Year WHO region  \
# 0   Life expectancy at birth (years)      Published  1990     Europe
# 1   Life expectancy at birth (years)      Published  2000     Europe
# 2  Life expectancy at age 60 (years)      Published  2012     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
# 2             High-income  Andorra      Female             28     28.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN

# %% [markdown]
#  Change the column name from any of the above file and store the changes made permanently.

# %%
df.rename(columns={"Indicator":"Indicator_Id"},inplace=True)
df.head(2)
# Out:
#                        Indicator_Id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# Change the names of multiple columns.

# %%
df.rename(columns={"PUBLISH STATES":"Publication Status","WHO region":"WHO Region"}, inplace = True)
df.head(2)
# Out:
#                        Indicator_Id Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# Arrange values of a particular column in ascending order.

# %%
df.sort_values(by ="Year").head(5)
# Out:
#                            Indicator_Id Publication Status  Year WHO Region  \
# 0      Life expectancy at birth (years)          Published  1990     Europe
# 1270   Life expectancy at birth (years)          Published  1990     Europe
# 3193   Life expectancy at birth (years)          Published  1990     Europe
# 3194   Life expectancy at birth (years)          Published  1990     Europe
# 3197  Life expectancy at age 60 (years)          Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# ...

# %% [markdown]
# Arrange multiple column values in ascending order.

# %%
df.sort_values(['Indicator_Id', 'Country','Year','WHO Region','Publication Status' ], ascending=[True, True,True,True,True])
# Out:
#                                          Indicator_Id Publication Status  \
# 2798  Healthy life expectancy (HALE) at birth (years)          Published
# 3363  Healthy life expectancy (HALE) at birth (years)          Published
# 4456  Healthy life expectancy (HALE) at birth (years)          Published
# 2245  Healthy life expectancy (HALE) at birth (years)          Published
# 3689  Healthy life expectancy (HALE) at birth (years)          Published
# 4457  Healthy life expectancy (HALE) at birth (years)          Published
# 2598  Healthy life expectancy (HALE) at birth (years)          Published
# 3690  Healthy life expectancy (HALE) at birth (years)          Published
# 3691  Healthy life expectancy (HALE) at birth (years)          Published
# 2599  Healthy life expectancy (HALE) at birth (years)          Published
# 3692  Healthy life expectancy (HALE) at birth (years)          Published
# 4064  Healthy life expectancy (HALE) at birth (years)          Published
# ...

# %% [markdown]
# Make country as the first column of the dataframe.

# %%
df[['Country','Indicator_Id', 'Publication Status', 'Year', 'WHO Region','World Bank income group', 'Sex', 'Display Value', 'Numeric','Low', 'High', 'Comments']].head(2)
# Out:
#    Country                      Indicator_Id Publication Status  Year  \
# 0  Andorra  Life expectancy at birth (years)          Published  1990
# 1  Andorra  Life expectancy at birth (years)          Published  2000
#
#   WHO Region World Bank income group         Sex  Display Value  Numeric  Low  \
# 0     Europe             High-income  Both sexes             77     77.0  NaN
# 1     Europe             High-income  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
#  Get the column array using a variable

# %%
df['WHO Region'].values.tolist()
np.array(df.Country)
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %% [markdown]
# Get the subset rows 11, 24, 37

# %%
df.iloc[[11,24,37]]
# Out:
#                          Indicator_Id Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %% [markdown]
# Get the subset rows excluding 5, 12, 23, and 56

# %%
df.drop(df.index[[5,12,23,56]]).head(7)
# Out:
#                         Indicator_Id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
# 6  Life expectancy at age 60 (years)          Published  1990
# 7  Life expectancy at age 60 (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
# ...

# %% [markdown]
# Load datasets from CSV

# %%
users =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.head(2)
# Out:
#    UserID     User Gender  Registered   Cancelled
# 0       1  Charles   male  2012-12-21         NaN
# 1       2    Pedro   male  2010-08-01  2010-08-08

# %%
sessions.head(2)
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2

# %%
transactions.head(2)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1

# %%
import numpy as np
import pandas as pd
# !pip install pandasql
from pandas import DataFrame, Series
import sqlite3 as db
# Out:
# ...
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from pandasql import sqldf

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
pysqldf("SELECT * FROM transactions where  UserID not in (SELECT UserID FROM users);")
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              9      2015-04-24     7.0          4         3

# %%
transactions.isin(users['UserID'])
# Out:
#    TransactionID  TransactionDate  UserID  ProductID  Quantity
# 0           True            False   False      False      True
# 1           True            False   False      False     False
# 2           True            False    True       True     False
# 3           True            False   False      False     False
# 4           True            False   False      False     False
# 5          False            False   False      False     False
# 6          False            False   False      False     False
# 7          False            False   False      False     False
# 8          False            False   False      False     False
# 9          False            False   False      False     False

# %% [markdown]
# Join users to transactions, keeping only rows from transactions and users that
# match via UserID (inner join)

# %%
pd.merge(transactions, users, on='UserID', how='inner')
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26      3          4         1  Caroline
# 1              3      2011-06-16      3          3         1  Caroline
# 2              7      2013-12-30      3          4         1  Caroline
# 3             10      2016-05-08      3          4         4  Caroline
# 4              4      2012-08-26      1          2         3   Charles
# 5              5      2013-06-06      2          4         1     Pedro
# 6              6      2013-12-23      2          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

# %%
pd.merge(users, transactions, on='UserID', how='outer').head(5)
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0     1.0   Charles    male  2012-12-21         NaN            4.0
# 1     2.0     Pedro    male  2010-08-01  2010-08-08            5.0
# 2     2.0     Pedro    male  2010-08-01  2010-08-08            6.0
# 3     3.0  Caroline  female  2012-10-23  2016-06-07            2.0
# 4     3.0  Caroline  female  2012-10-23  2016-06-07            3.0
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2013-12-23        5.0       6.0
# 3      2011-05-26        4.0       1.0
# 4      2011-06-16        3.0       1.0

# %% [markdown]
# Determine which sessions occurred on the same day each user registered

# %%
pd.merge(users, sessions, on=['UserID'], how='inner')
#17 - create a df with constant column for user and product and merge it based on commonkey
# Out:
#    UserID      User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2     Pedro    male  2010-08-01  2010-08-08          1  2010-01-05
# 1       2     Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 2       2     Pedro    male  2010-08-01  2010-08-08          3  2010-11-25
# 3       3  Caroline  female  2012-10-23  2016-06-07          7  2012-12-21
# 4       4   Brielle  female  2013-07-17         NaN          5  2011-10-19
# 5       4   Brielle  female  2013-07-17         NaN          6  2012-10-23
# 6       4   Brielle  female  2013-07-17         NaN          8  2013-05-22
# 7       4   Brielle  female  2013-07-17         NaN          9  2013-07-17
# 8       4   Brielle  female  2013-07-17         NaN         10  2016-01-11
# 9       5  Benjamin    male  2010-11-25         NaN          4  2011-09-21

# %% [markdown]
# Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
pd.merge(users, transactions, on=['UserID'], how='outer')
# Out:
#     UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0      1.0   Charles    male  2012-12-21         NaN            4.0
# 1      2.0     Pedro    male  2010-08-01  2010-08-08            5.0
# 2      2.0     Pedro    male  2010-08-01  2010-08-08            6.0
# 3      3.0  Caroline  female  2012-10-23  2016-06-07            2.0
# 4      3.0  Caroline  female  2012-10-23  2016-06-07            3.0
# 5      3.0  Caroline  female  2012-10-23  2016-06-07            7.0
# 6      3.0  Caroline  female  2012-10-23  2016-06-07           10.0
# 7      4.0   Brielle  female  2013-07-17         NaN            NaN
# 8      5.0  Benjamin    male  2010-11-25         NaN            NaN
# 9      7.0       NaN     NaN         NaN         NaN            1.0
# 10     7.0       NaN     NaN         NaN         NaN            9.0
# 11     NaN       NaN     NaN         NaN         NaN            8.0
#
#    TransactionDate  ProductID  Quantity
# 0       2012-08-26        2.0       3.0
# ...

# %% [markdown]
# 18. Determine how much quantity of each product was purchased by each user

# %%
g1 = transactions.groupby(["UserID", "Quantity"], as_index=False).count()
g2=pd.merge(users, g1, on=['UserID'], how='inner')
g2[['UserID','ProductID','Quantity']]
# Out:
#   UserID  ProductID  Quantity
# 0      1          1         3
# 1      2          1         1
# 2      2          1         6
# 3      3          3         1
# 4      3          1         4

# %% [markdown]
# 19. For each user, get each possible pair of pair transactions (TransactionID1,TransacationID2)

# %%
pd.merge(transactions,transactions,on=['ProductID','UserID'])
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID  Quantity_x  \
# 0                 1        2010-08-21     7.0          2           1
# 1                 2        2011-05-26     3.0          4           1
# 2                 2        2011-05-26     3.0          4           1
# 3                 2        2011-05-26     3.0          4           1
# 4                 7        2013-12-30     3.0          4           1
# 5                 7        2013-12-30     3.0          4           1
# 6                 7        2013-12-30     3.0          4           1
# 7                10        2016-05-08     3.0          4           4
# 8                10        2016-05-08     3.0          4           4
# 9                10        2016-05-08     3.0          4           4
# 10                3        2011-06-16     3.0          3           1
# 11                4        2012-08-26     1.0          2           3
# 12                5        2013-06-06     2.0          4           1
# ...

# %% [markdown]
# Join each user to his/her first occuring transaction in the transactions table

# %%
pd.merge(users,transactions,on='UserID')[['UserID', 'ProductID']]
# Out:
#   UserID  ProductID
# 0      1          2
# 1      2          4
# 2      2          5
# 3      3          4
# 4      3          3
# 5      3          4
# 6      3          4

# %% [markdown]
# Test to see if we can drop columns

# %%
data=pd.merge(users,transactions,on='UserID',how='left')
my_columns = list(new.columns)
col=my_columns
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
list(data.dropna(thresh=int(data.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
missing_info = list(data.columns[data.isnull().any()])
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
num_missing = data[data[missing_info].isnull() == True].shape[0]
print('number missing for column {}: {}'.format(missing_info, num_missing))
# Out:
# number missing for column ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']: 9

# %%
num_missing = data[data[col].isnull() == True].shape[0]
print('number missing for column {}: {}'.format(col, num_missing)) #count of missing data
for col in missing_info:
    percent_missing = data[data[col].isnull() == True].shape[0] / data.shape[0]
    print('percent missing for column {}: {}'.format(col, percent_missing))
# Out:
# number missing for column ['UserID', 'User', 'Gender', 'Registered', 'Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']: 9
# percent missing for column Cancelled: 0.3333333333333333
# percent missing for column TransactionID: 0.2222222222222222
# percent missing for column TransactionDate: 0.2222222222222222
# percent missing for column ProductID: 0.2222222222222222
# percent missing for column Quantity: 0.2222222222222222
